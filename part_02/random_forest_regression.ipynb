# %% [markdown]
# #### Random forest intuition
# <small>
#
# 1. pick at random k data points from the training set
# 2. build the decision tree associated to these k data points
# 3. choose the number Ntree to trees you want to build and repeat steps 1 & 2
# 4. for a new data point, make each one of your Ntree trees predict the value of Y to for the data points in question, and assign the new data point the average across all of the predicted Y values
#
# </small>

# %% [markdown]
# 1. Importing the libraries

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %% [markdown]
# 2. Importing the dataset

# %%
dataset = pd.read_csv('datasets/Position_Salaries.csv')
X = dataset.iloc[:, 1: -1]
y = dataset.iloc[:, -1]

# %% [markdown]
# 3. Training the Random Forest Regression model on the whole dataset

# %%
# n_estimators = no of trees
# typically of the same size as the original dataset
# repeatation allowed
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X, y)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %% [markdown]
# 4. predicting a new result

# %%
regressor.predict([[6.5], [4]])
# Out:
# c:\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([167000.,  74000.])

# %% [markdown]
# 5. Visualising the Random Forest Regression results (higher resolution)

# %%
X = np.array(X, dtype=float)
X_grid = np.arange(min(X), max(X), 0.1).reshape(-1, 1)
plt.scatter(X, y, color='red')
plt.plot(X_grid, regressor.predict(X_grid), color='blue')
plt.title('Truth or Bluff (SVR)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10868\1900563723.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1).reshape(-1, 1)
# c:\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
